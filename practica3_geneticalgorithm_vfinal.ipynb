# %% [markdown]
# <a href="https://colab.research.google.com/github/RogerReateguiUTEC/TareasIAFundamentals/blob/main/practica3_geneticalgorithm_vfinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.spatial.distance import pdist, squareform
from matplotlib import pyplot as plt
import random

# %% [markdown]
# # 1. DEFINICIÓN DE LAS FUNCIONES

# %%
def plot_tsp(cities, route):
    x = [node[0] for node in cities]
    y = [node[1] for node in cities]

    plt.figure(figsize=(8, 6))
    plt.scatter(x, y, color='blue', zorder=2)  #Graficando los nodos

    # for i in range(len(cities)):
    #     plt.text(cities[i][0], cities[i][1], f'({round(cities[i][0],3)}, {round(cities[i][1],3)})', fontsize=8) #etiquetas en cada coordenada de ciudad


    for i in range(len(route) - 1):
        node1 = route[i]
        node2 = route[i + 1]
        plt.plot([cities[node1][0], cities[node2][0]], [cities[node1][1], cities[node2][1]], color='red', zorder=1)  # Plot route

    # Connect the last node to the first node to form a loop
    #node1 = route[-1]
    #node2 = route[0]
    #plt.plot([cities[node1][0], cities[node2][0]], [cities[node1][1], cities[node2][1]], color='red', zorder=1)  # Plot route

    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('TSP Nodes and Route')
    plt.grid(True)
    plt.show()

# %%
def fitness(solution):
  distance = 0
  for i in range(len(solution)-1):
    distance += distances[solution[i]][solution[i+1]]
  return distance

# %%
def create_initial_population(pop_size, num_cities):
  population = [] #vector de soluciones
  for i in range(pop_size):
    # crear solucion
    individual = list(np.random.permutation(num_cities)) #genotipos
    population.append(individual)

  return population

# %%
def fill_child(child, parent, end):
    size = len(parent)
    current_pos = (end + 1) % size
    for gene in parent:
        if gene not in child:
            child[current_pos] = gene
            current_pos = (current_pos + 1) % size

def ordered_crossover(parent1, parent2):
  size = len(parent1)
  child1 = [-1]*size
  child2 = [-1]*size

  start, end = sorted( random.sample(range(size), 2 ))

  child1[start:end+1] = parent2[start:end+1]
  child2[start:end+1] = parent1[start:end+1]

  fill_child(child1, parent1, end)
  fill_child(child2, parent2, end)

  return child1, child2

# %%
def swap_mutate(individual):
  i, j = np.random.choice(len(individual), 2, replace=False)
  new_individual = individual.copy()
  new_individual[i], new_individual[j] = individual[j], individual[i]
  return new_individual

# %%
def select_elite(population, all_fitness, elite_size):   # selecciona los que tengan el mejor fitness
  elite_indices = np.argsort(all_fitness)[:elite_size]
  return np.array(population)[elite_indices], elite_indices

# %% [markdown]
# ## Funciones de selección

# %%
def rank_based_selection(population, all_fitness):
  all_fitness_sorted = sorted(all_fitness)
  rank = [i + 1 for i in range(len(all_fitness_sorted))]
  total_rank = sum(rank)
  selection_probs = [r / total_rank for r in rank]
  return population[np.random.choice(len(population), p=selection_probs)]

# %%
def roulete_wheel_selection_minimization(population, all_fitness):
    max_fitness = max(all_fitness)
    inverted_fitness = [max_fitness - f for f in all_fitness]  # invert fitness
    total_fitness = sum(inverted_fitness)
    selection_probs = [f / total_fitness for f in inverted_fitness]
    return population[np.random.choice(len(population), p=selection_probs)]

# %%
def fitness_scaling_selection(population, all_fitness):
  min_scale = 50
  max_scale = 100

  highest_fitness = max(all_fitness)
  inverted_fitness = [highest_fitness - f for f in all_fitness]

  min_fitness = min(inverted_fitness)
  max_fitness = max(inverted_fitness)

  a = (max_scale - min_scale) / (max_fitness - min_fitness)
  b = min_scale - a * min_fitness

  scaled_fitness = [a*f + b for f in inverted_fitness]
  total_fitness = sum(scaled_fitness)
  selection_probs = [f / total_fitness for f in scaled_fitness]
  return population[np.random.choice(len(population), p=selection_probs)]

# %%
def tournament_selection(population, all_fitness):
  tournament_size = 3
  tournament_indices = np.random.choice(len(all_fitness), tournament_size, replace=False)

  tournament_fitness = [all_fitness[i] for i in tournament_indices]

  winner_index = tournament_indices[np.argmin(tournament_fitness)]
  return population[winner_index]

# %% [markdown]
# ## Ejecución del algoritmo genético

# %%
def genetic_algorithm_experiment1(distance_matrix, mutation_rate, generations, selectionMethod):
  num_cities = distance_matrix.shape[0]
  history = []
  generation_history = []

  #1. INICIALIZACION DE LA POBLACION (RANDOM):
  population = create_initial_population(pop_size, N) #[[45,15,...n50],[42,26,...n50]...[m100]] #orden en que el TSP irá a cada ciudad (primero a la 45, luego a la 15, etc.)

  #Hallamos el fitness de cada solución en la población (lista de distancias totales)
  all_fitness = [ fitness(sol) for sol in population ]

  for generation in range(generations):
    new_population = []


    #Se guardan los mejores de la antigua población
    selected_elite, indices = select_elite(population, all_fitness, elite_size)
    new_population.extend( selected_elite )

    while len(new_population) < pop_size:
      #2. SELECCION: Escogemos una muestra de la población por distintos métodos
      if selectionMethod == "roulette":
        parent1 = roulete_wheel_selection_minimization(population, all_fitness)
        parent2 = roulete_wheel_selection_minimization(population, all_fitness)
      elif selectionMethod == "rank":
        parent1 = rank_based_selection(population, all_fitness)
        parent2 = rank_based_selection(population, all_fitness)
      elif selectionMethod == "fitness-scaling":
        parent1 = fitness_scaling_selection(population, all_fitness)
        parent2 = fitness_scaling_selection(population, all_fitness)
      elif selectionMethod == "tournament":
        parent1 = tournament_selection(population, all_fitness)
        parent2 = tournament_selection(population, all_fitness)
      else:
        raise ValueError("Invalid selection method")


      #3. CROSSOVER:
      child1, child2 = ordered_crossover(parent1, parent2)

      #4.MUTATION:
      if random.random() < mutation_rate:
        child1 = swap_mutate(child1)

      if random.random() < mutation_rate:
        child2 = swap_mutate(child2)

      #5.SUBSTITUTION:
      new_population.extend([child1, child2])

    population = new_population[:pop_size]
    all_fitness = [ fitness(sol) for sol in population ]

    if generation % 50 == 0:
      history.append([min(all_fitness)])
      generation_history.append([generation])

    if generation % 500 == 0:
      print(f"Generation {generation} | Best distance: {min(all_fitness)}")


  best_route_index = np.argmin(all_fitness)
  best_route = population[best_route_index]
  best_distance = all_fitness[best_route_index]

  print(f"Final best distance: {best_distance}")
  return best_route, best_distance, history, generation_history

# %% [markdown]
# # 2. EJECUCIÓN DEL PROBLEMA

# %%
# HYPERPARAMETROS:

pop_size = 100 #cantidad de soluciones (población o genomas)
N = 100 #cantidad de ciudades
elite_size = 50 #elite de soluciones que se mantiene en cada generación
mutation_rate = 0.01 #probabilidad para la mutación de cada hijo
generations = 5000 #cantidad de generaciones o iteraciones


cities = np.random.rand(N, 2) #matriz de coordenadas para cada ciudad
distances = squareform(pdist(cities, 'euclidean')) #matriz con arrays con las distancias entre las ciudades

# %%
best_route, best_distance, history_roulette, generation_history = genetic_algorithm_experiment1(distances, mutation_rate, generations, "roulette")
plot_tsp(cities, best_route)
# Out:
# Generation 0 | Best distance: 46.37774420569086
# Generation 500 | Best distance: 15.418064509034014
# Generation 1000 | Best distance: 11.825494390885455
# Generation 1500 | Best distance: 11.704297227919149
# Generation 2000 | Best distance: 11.60759751600646
# Generation 2500 | Best distance: 11.428785383126218
# Generation 3000 | Best distance: 11.397277524567173
# Generation 3500 | Best distance: 11.340398718024023
# Generation 4000 | Best distance: 11.28087929671416
# Generation 4500 | Best distance: 11.270152275293228
# Final best distance: 11.258572937310431

# %%
best_route, best_distance, history_rank, generation_history = genetic_algorithm_experiment1(distances, mutation_rate, generations, "rank")
plot_tsp(cities, best_route)
# Out:
# Generation 0 | Best distance: 47.52233227822416
# Generation 500 | Best distance: 30.470001157082102
# Generation 1000 | Best distance: 27.382133283118375
# Generation 1500 | Best distance: 24.87939750941099
# Generation 2000 | Best distance: 23.101840246421517
# Generation 2500 | Best distance: 22.27219525455002
# Generation 3000 | Best distance: 20.054157346022468
# Generation 3500 | Best distance: 18.22583241309089
# Generation 4000 | Best distance: 17.310043850992514
# Generation 4500 | Best distance: 16.011024644645538
# Final best distance: 14.896185277241496

# %%
best_route, best_distance, history_fitness_scaling, generation_history = genetic_algorithm_experiment1(distances, mutation_rate, generations, "fitness-scaling")
plot_tsp(cities, best_route)
# Out:
# Generation 0 | Best distance: 46.98644383417607
# Generation 500 | Best distance: 18.39407551803625
# Generation 1000 | Best distance: 14.251238928489435
# Generation 1500 | Best distance: 12.745547746935456
# Generation 2000 | Best distance: 12.077741238555902
# Generation 2500 | Best distance: 11.828871978795666
# Generation 3000 | Best distance: 11.106358265547282
# Generation 3500 | Best distance: 11.062042671516027
# Generation 4000 | Best distance: 10.855652833248508
# Generation 4500 | Best distance: 10.66802374858034
# Final best distance: 10.59309186348878

# %%
best_route, best_distance, history_tournament, generation_history = genetic_algorithm_experiment1(distances, mutation_rate, generations, "tournament")
plot_tsp(cities, best_route)
# Out:
# Generation 0 | Best distance: 46.80528380457201
# Generation 500 | Best distance: 14.294715816420815
# Generation 1000 | Best distance: 13.539680955466478
# Generation 1500 | Best distance: 12.681544735486055
# Generation 2000 | Best distance: 11.675555446434347
# Generation 2500 | Best distance: 11.148224271581613
# Generation 3000 | Best distance: 10.914490884759259
# Generation 3500 | Best distance: 10.717056184677295
# Generation 4000 | Best distance: 10.644623259656582
# Generation 4500 | Best distance: 10.644623259656582
# Final best distance: 10.558797304553542

# %% [markdown]
# # 3.GRÁFICA DEL PROBLEMA

# %%
plt.figure(figsize=(15, 6))
plt.plot(generation_history, history_roulette, linestyle='-', color='red', label="Roulette wheel selection")
plt.plot(generation_history, history_rank, linestyle='-', color='blue', label="Rank-based selection")
plt.plot(generation_history, history_fitness_scaling, linestyle='-', color='green', label="Fitness Scaling selection")
plt.plot(generation_history, history_tournament, linestyle='-', color='purple', label="Tournament selection")
plt.xlabel('Generación')
plt.ylabel('"Fitness" (Distancia total) de cada solución')
plt.title('Evolución del fitness en cada generación')
plt.legend()
plt.show()
